# %% [markdown]
# <a href="https://colab.research.google.com/github/Mekondjo-EDSA/dsi_repo/blob/master/Grassify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import packages
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
from fastbook import *
# !pip install fastai -U
import fastai
from fastai.vision.all import *

# %%
# initialize learner and widgets
path = Path('/content/gdrive/MyDrive/grass')
learn_inf = load_learner(path/'export.pkl', cpu=True)
output = widgets.Output()
btn_upload = widgets.FileUpload()
lbl_pred = widgets.Label()

# %%
# callback function
def on_data_change(change):
    lbl_pred.value = ''
    img = PILImage.create(btn_upload.data[-1])
    output.clear_output()
    with output:
        display(img.to_thumb(224, 224))
    pred, pred_id, probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_id]:.04f}'

# %%
# register callback with upload button
btn_upload.observe(on_data_change, names=['data'])

# %%
# display widgets
from ipywidgets import VBox
display(VBox([widgets.Label('Choose an image!'), btn_upload, output, lbl_pred]))
# Out:
# VBox(children=(Label(value='Choose an image!'), FileUpload(value={}, description='Upload'), Output(), Label(va…
